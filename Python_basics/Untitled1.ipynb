# %%
#This is LifeExPlot.py

# Importing packages
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

#Reading file
my_file = pd.read_table("gapminder.txt")

Canada = my_file.loc[my_file['country']=="Canada", :]

#This is LifeExPlot.pyprint(Canada)

Canada.plot.line(x="year",y="lifeExp", label="Life Expectancy", figsize=(8,6))
plt.suptitle("Life Expectancy in Canada over the years", fontsize=20)
plt.xlabel("Year",fontsize=16)
plt.savefig("PlotlifeExp.png")

# %%
my_file.iloc[:,[3,5]]
# Out:
#       lifeExp    gdpPercap
# 0      28.801   779.445314
# 1      30.332   820.853030
# 2      31.997   853.100710
# 3      34.020   836.197138
# 4      36.088   739.981106
# 5      38.438   786.113360
# 6      39.854   978.011439
# 7      40.822   852.395945
# 8      41.674   649.341395
# 9      41.763   635.341351
# 10     42.129   726.734055
# 11     43.828   974.580338
# 12     55.230  1601.056136
# 13     59.280  1942.284244
# 14     64.820  2312.888958
# 15     66.220  2760.196931
# 16     67.690  3313.422188
# 17     68.930  3533.003910
# 18     70.420  3630.880722
# 19     72.000  3738.932735
# 20     71.581  2497.437901
# 21     72.950  3193.054604
# 22     75.651  4604.211737
# 23     76.423  5937.029526
# 24     43.077  2449.008185
# 25     45.685  3013.976023
# 26     48.303  2550.816880
# 27     51.407  3246.991771
# 28     54.518  4182.663766
# 29     58.014  4910.416756
# ...       ...          ...
# 1674   49.113  1977.557010
# 1675   52.922  1971.741538
# ...

# %%
my_file.loc[my_file['country']=='Sweden']
# Out:
#      country continent  year  lifeExp      pop     gdpPercap
# 1464  Sweden    Europe  1952   71.860  7124673   8527.844662
# 1465  Sweden    Europe  1957   72.490  7363802   9911.878226
# 1466  Sweden    Europe  1962   73.370  7561588  12329.441920
# 1467  Sweden    Europe  1967   74.160  7867931  15258.296970
# 1468  Sweden    Europe  1972   74.720  8122293  17832.024640
# 1469  Sweden    Europe  1977   75.440  8251648  18855.725210
# 1470  Sweden    Europe  1982   76.420  8325260  20667.381250
# 1471  Sweden    Europe  1987   77.190  8421403  23586.929270
# 1472  Sweden    Europe  1992   78.160  8718867  23880.016830
# 1473  Sweden    Europe  1997   79.390  8897619  25266.594990
# 1474  Sweden    Europe  2002   80.040  8954175  29341.630930
# 1475  Sweden    Europe  2007   80.884  9031088  33859.748350

# %%
ls = my_file['lifeExp']=="70"
# Out:
# /Users/susana/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py:816: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-82baddf42c4d> in <module>()
# ----> 1 ls = my_file['lifeExp']=="70"
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     877
#     878             with np.errstate(all='ignore'):
# --> 879                 res = na_op(values, other)
#     880             if is_scalar(res):
#     881                 raise TypeError('Could not compare {typ} type with Series'
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     816                     result = getattr(x, name)(y)
# ...

# %%
def get_country(country_name):
    country = my_file.loc[my_file['country']==country_name, :]
    return country

# %%
get_country('India')
# Out:
#     country continent  year  lifeExp         pop    gdpPercap
# 696   India      Asia  1952   37.373   372000000   546.565749
# 697   India      Asia  1957   40.249   409000000   590.061996
# 698   India      Asia  1962   43.605   454000000   658.347151
# 699   India      Asia  1967   47.193   506000000   700.770611
# 700   India      Asia  1972   50.651   567000000   724.032527
# 701   India      Asia  1977   54.208   634000000   813.337323
# 702   India      Asia  1982   56.596   708000000   855.723538
# 703   India      Asia  1987   58.553   788000000   976.512676
# 704   India      Asia  1992   60.223   872000000  1164.406809
# 705   India      Asia  1997   61.765   959000000  1458.817442
# 706   India      Asia  2002   62.879  1034172547  1746.769454
# 707   India      Asia  2007   64.698  1110396331  2452.210407

# %%
def plot_country(country_name):
    Canada.plot.line(x="year",y="lifeExp", label="Life Expectancy", figsize=(8,6))
plt.suptitle("Life Expectancy in Canada over the years", fontsize=20)
plt.xlabel("Year",fontsize=16)
plt.savefig("PlotlifeExp.png")
# Out:
#   File "<ipython-input-6-0f20f9541452>", line 1
#     def plot_country(country_name)
#                                   ^
# SyntaxError: invalid syntax

# %%
def get_country(country_name):
    country = my_file.loc[my_file['country']==country_name, :]
    return country

# %%
get_country("India")
# Out:
#     country continent  year  lifeExp         pop    gdpPercap
# 696   India      Asia  1952   37.373   372000000   546.565749
# 697   India      Asia  1957   40.249   409000000   590.061996
# 698   India      Asia  1962   43.605   454000000   658.347151
# 699   India      Asia  1967   47.193   506000000   700.770611
# 700   India      Asia  1972   50.651   567000000   724.032527
# 701   India      Asia  1977   54.208   634000000   813.337323
# 702   India      Asia  1982   56.596   708000000   855.723538
# 703   India      Asia  1987   58.553   788000000   976.512676
# 704   India      Asia  1992   60.223   872000000  1164.406809
# 705   India      Asia  1997   61.765   959000000  1458.817442
# 706   India      Asia  2002   62.879  1034172547  1746.769454
# 707   India      Asia  2007   64.698  1110396331  2452.210407

# %%
def plot_country_2(country):
    country.plot.line(x="year",y="gdpPercap", label="Life Expectancy", figsize=(8,6))
plt.suptitle("GDPPerCap over the years", fontsize=20)
plt.xlabel("Year",fontsize=16)
# Out:
# Text(0.5,0,'Year')

# %%
plot_country(Canada)

# %%
country= get_country('India')

# %%
plot_country(country)

# %% [raw]
# Argentina= get_country(Argentina)

# %%
plot_country=(Argentina)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-709cb0f34692> in <module>()
# ----> 1 plot_country=(Argentina)
#
# NameError: name 'Argentina' is not defined

# %%
get_country('Argentina')
# Out:
#       country continent  year  lifeExp       pop     gdpPercap
# 48  Argentina  Americas  1952   62.485  17876956   5911.315053
# 49  Argentina  Americas  1957   64.399  19610538   6856.856212
# 50  Argentina  Americas  1962   65.142  21283783   7133.166023
# 51  Argentina  Americas  1967   65.634  22934225   8052.953021
# 52  Argentina  Americas  1972   67.065  24779799   9443.038526
# 53  Argentina  Americas  1977   68.481  26983828  10079.026740
# 54  Argentina  Americas  1982   69.942  29341374   8997.897412
# 55  Argentina  Americas  1987   70.774  31620918   9139.671389
# 56  Argentina  Americas  1992   71.868  33958947   9308.418710
# 57  Argentina  Americas  1997   73.275  36203463  10967.281950
# 58  Argentina  Americas  2002   74.340  38331121   8797.640716
# 59  Argentina  Americas  2007   75.320  40301927  12779.379640

# %%
Argentina = my_file.loc[my_file['country']=="Argentina", :]

# %%
Argentina
# Out:
#       country continent  year  lifeExp       pop     gdpPercap
# 48  Argentina  Americas  1952   62.485  17876956   5911.315053
# 49  Argentina  Americas  1957   64.399  19610538   6856.856212
# 50  Argentina  Americas  1962   65.142  21283783   7133.166023
# 51  Argentina  Americas  1967   65.634  22934225   8052.953021
# 52  Argentina  Americas  1972   67.065  24779799   9443.038526
# 53  Argentina  Americas  1977   68.481  26983828  10079.026740
# 54  Argentina  Americas  1982   69.942  29341374   8997.897412
# 55  Argentina  Americas  1987   70.774  31620918   9139.671389
# 56  Argentina  Americas  1992   71.868  33958947   9308.418710
# 57  Argentina  Americas  1997   73.275  36203463  10967.281950
# 58  Argentina  Americas  2002   74.340  38331121   8797.640716
# 59  Argentina  Americas  2007   75.320  40301927  12779.379640

# %%
 Argentina.plot.line(x="year",y="gdpPercap", label="Life Expectancy", figsize=(8,6))
plt.suptitle("Life Expectancy over the years", fontsize=20)
plt.xlabel("year",fontsize=16)
# Out:
# Text(0.5,0,'year')

# %%
a=get_country ('India')
plot_country_2(a)

# %%
import pandas as pd
from plotnine import *
my_file = pd.read_table('gapminder.txt')

# %%
my_file
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
(ggplot(my_file) + aes(x='gdpPercap',y='lifeExp')+ geom_point())
# Out:
# <ggplot: (7546914003)>

# %%
(ggplot(my_file) + aes(x='pop',y='lifeExp')+ geom_point())
# Out:
# <ggplot: (296061283)>

# %%
(ggplot(my_file) + aes(x='year',y='lifeExp', color='continent')+ geom_point())
# Out:
# <ggplot: (7547245239)>

# %%
(ggplot(my_file) + aes(x='year',y='lifeExp', color='continent')+ geom_line())
# Out:
# <ggplot: (7547220842)>

# %%
(ggplot(my_file) + aes(x='year',y='lifeExp', color='continent', by='country')+ geom_line())
# Out:
# <ggplot: (7547361505)>

# %%
(ggplot(my_file) + aes(x='year',y='lifeExp', color='continent', by='country')+ geom_point() + geom_line())
# Out:
# <ggplot: (-9223372029307541977)>

# %%
(ggplot(my_file) + aes(x='year',y='lifeExp', color='continent', by='country')+ geom_line() + geom_point())
# Out:
# <ggplot: (7547733147)>
